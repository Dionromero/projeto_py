# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.cluster as cluster 

from sklearn.preprocessing import OneHotEncoder
from sklearn.datasets import make_blobs

#gerar dados 
x, y = make_blobs(n_samples=20, n_features=2, centers=3, random_state=1)

#plot inicial
plt.scatter(df['feature_1'], df['feature_2'], s=100, linewidths=1, c=df['cluster'], edgecolors='black')
plt.xlabel('feature 1')
plt.ylabel('feature 2')


#modelo kMeans
model_kmeans = cluster.KMeans(n_clusters = 3, random_state = 0)
model_kmeans.fit(x)

#prever clusters 
labels = model_kmeans.predict(x)

#plot dos clusters previstos
plt.scatter(x[:,0], x[:,1], s=100, c=labels, cmap='viridis', edgecolors='black')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Clusters encontrados pelo K-Means')
plt.show()

#teste 
calor = np.random.uniform(-12, 0, 5)
frio = np.random.uniform(-10,5,5)
x_test = np.column_stack((calor, frio))
test_labels = model_kmeans.predict(x_test)
print("Clusters dos novos pontos:", test_labels)
# Out:
# Clusters dos novos pontos: [1 2 1 1 1]

# %%
from datasets import load_dataset
dataset = load_dataset("ghoumrassi/clothes_sample")

#transformar o dataset de treino em pandas dataframe
df_train = pd.DataFrame(dataset['train'])

#mostrar as 10 priomeiros linhas 
print(df_train.head(10))
# Out:
#                                                image  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 4  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 5  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 6  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 7  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 8  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 9  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                                 text
# 0  Mulberry Blue Zipped Backpack leather bag. a b...
# 1  Balenciaga Black Track leather low trainers. a...
# 2    Gucci Brown Leather vest. a black leather vest.
# 3  Balenciaga Beige Wool pull. a sweater with bla...
# 4  Mulberry Multicolour Cloth travel bag. a blue ...
# 5  Saint Laurent Beige Wyatt Jodphur boots. a tan...
# ...

# %%
import pandas as pd

df_train = pd.DataFrame(dataset['train'])
print(df_train.head(10))
# Out:
#                                                image  \
# 0  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 4  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 5  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 6  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 7  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 8  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 9  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
#                                                 text
# 0  Mulberry Blue Zipped Backpack leather bag. a b...
# 1  Balenciaga Black Track leather low trainers. a...
# 2    Gucci Brown Leather vest. a black leather vest.
# 3  Balenciaga Beige Wool pull. a sweater with bla...
# 4  Mulberry Multicolour Cloth travel bag. a blue ...
# 5  Saint Laurent Beige Wyatt Jodphur boots. a tan...
# ...
