# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.cluster as cluster 
import requests

from sklearn.preprocessing import OneHotEncoder
from sklearn.datasets import make_blobs

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
API_KEY = "8edf5a3557214b83a8d24412250109"
local = "Curitiba"  # pode ser "Curitiba, Brazil" ou latitude,longitude
url = "http://api.weatherapi.com/v1/forecast.json"
params = {
    "key": API_KEY,
    "q": local,
    "lang": "pt",     # opcional: traduz descrições para português
    "aqi": "no"       # opcional: inclui dados de qualidade do ar
}

try:
    response = requests.get(url, params=params)
    response.raise_for_status()
    dados = response.json()
    
    # Exemplo de como acessar alguns dados:
    # temperatura = dados["current"]["temp_c"]
    # descricao = dados["current"]["condition"]["text"]
    # umidade = dados["current"]["humidity"]
    # vento = dados["current"]["wind_kph"]

    # print(f"Tempo em {dados['location']['name']}: {descricao.capitalize()}")
    # print(f"Temperatura: {temperatura} °C")
    # print(f"Umidade: {umidade}%")
    # print(f"Vento: {vento} km/h")
   # print(dados)

except requests.exceptions.HTTPError as err:
    print(f"Erro HTTP: {err} — código: {response.status_code}")
except ValueError:
    print("Erro ao decodificar JSON.")
except Exception as e:
    print(f"Ocorreu um erro: {e}")

df = pd.json_normalize(dados)
df
# Out:
#   location.name location.region location.country  location.lat  location.lon  \
# 0      Curitiba          Parana           Brazil      -25.4167        -49.25
#
#       location.tz_id  location.localtime_epoch location.localtime  \
# 0  America/Sao_Paulo                1756696602   2025-09-01 00:16
#
#    current.last_updated_epoch current.last_updated  current.temp_c  \
# 0                  1756696500     2025-09-01 00:15            14.1
#
#    current.temp_f  current.is_day current.condition.text  \
# 0            57.4               0   Parcialmente nublado
#
#                              current.condition.icon  current.condition.code  \
# 0  //cdn.weatherapi.com/weather/64x64/night/116.png                    1003
#
#    current.wind_mph  current.wind_kph  current.wind_degree current.wind_dir  \
# 0               7.8              12.6                   83                E
#
#    current.pressure_mb  current.pressure_in  current.precip_mm  \
# 0               1024.0                30.25                0.0
#
#    current.precip_in  current.humidity  current.cloud  current.feelslike_c  \
# 0                0.0                87             58                 13.2
#
#    current.feelslike_f  current.windchill_c  current.windchill_f  \
# 0                 55.8                 13.2                 55.8
#
#    current.heatindex_c  current.heatindex_f  current.dewpoint_c  \
# 0                 14.1                 57.4                12.0
#
#    current.dewpoint_f  current.vis_km  current.vis_miles  current.uv  \
# 0                53.6            10.0                6.0         0.0
#
#    current.gust_mph  current.gust_kph  current.short_rad  current.diff_rad  \
# 0              10.7              17.2                  0                 0
#
#    current.dni  current.gti                               forecast.forecastday
# 0            0            0  [{'date': '2025-09-01', 'date_epoch': 17566848...

# %%
forecast_list = dados["forecast"]["forecastday"]
df_forecast = pd.json_normalize(forecast_list)
df_forecast
# Out:
#          date  date_epoch                                               hour  \
# 0  2025-09-01  1756684800  [{'time_epoch': 1756695600, 'time': '2025-09-0...
#
#    day.maxtemp_c  day.maxtemp_f  day.mintemp_c  day.mintemp_f  day.avgtemp_c  \
# 0           21.3           70.3           13.9           57.0           16.1
#
#    day.avgtemp_f  day.maxwind_mph  day.maxwind_kph  day.totalprecip_mm  \
# 0           60.9              9.4             15.1                0.31
#
#    day.totalprecip_in  day.totalsnow_cm  day.avgvis_km  day.avgvis_miles  \
# 0                0.01               0.0           10.0               6.0
#
#    day.avghumidity  day.daily_will_it_rain  day.daily_chance_of_rain  \
# 0               81                       1                        81
#
#    day.daily_will_it_snow  day.daily_chance_of_snow  \
# 0                       0                         0
#
#                  day.condition.text  \
# 0  Possibilidade de chuva irregular
#
#                                day.condition.icon  day.condition.code  day.uv  \
# 0  //cdn.weatherapi.com/weather/64x64/day/176.png                1063     1.4
#
#   astro.sunrise astro.sunset astro.moonrise astro.moonset astro.moon_phase  \
# 0      06:29 AM     06:05 PM       12:09 PM      01:45 AM   Waxing Gibbous
#
#    astro.moon_illumination  astro.is_moon_up  astro.is_sun_up
# 0                       57                 1                0

# %%
hour_list = dados["forecast"]["forecastday"][0]["hour"]
df_hour = pd.json_normalize(hour_list)
df_hour
# Out:
#     time_epoch              time  temp_c  temp_f  is_day  wind_mph  wind_kph  \
# 0   1756695600  2025-09-01 00:00    14.1    57.5       0       8.9      14.4
# 1   1756699200  2025-09-01 01:00    14.1    57.4       0       7.8      12.6
# 2   1756702800  2025-09-01 02:00    14.2    57.6       0       7.6      12.2
# 3   1756706400  2025-09-01 03:00    14.2    57.5       0       5.8       9.4
# 4   1756710000  2025-09-01 04:00    13.9    57.0       0       6.3      10.1
# 5   1756713600  2025-09-01 05:00    14.2    57.6       0       7.4      11.9
# 6   1756717200  2025-09-01 06:00    14.3    57.7       0       6.7      10.8
# 7   1756720800  2025-09-01 07:00    14.9    58.9       1       7.2      11.5
# 8   1756724400  2025-09-01 08:00    15.4    59.8       1       7.6      12.2
# 9   1756728000  2025-09-01 09:00    15.7    60.3       1       6.7      10.8
# 10  1756731600  2025-09-01 10:00    17.8    64.1       1       7.2      11.5
# 11  1756735200  2025-09-01 11:00    19.6    67.2       1       7.8      12.6
# 12  1756738800  2025-09-01 12:00    20.9    69.5       1       8.3      13.3
# 13  1756742400  2025-09-01 13:00    21.3    70.3       1       8.3      13.3
# 14  1756746000  2025-09-01 14:00    20.5    68.9       1       8.5      13.7
# 15  1756749600  2025-09-01 15:00    19.3    66.8       1       8.5      13.7
# 16  1756753200  2025-09-01 16:00    18.0    64.3       1       8.7      14.0
# 17  1756756800  2025-09-01 17:00    15.6    60.1       1       8.3      13.3
# 18  1756760400  2025-09-01 18:00    14.7    58.5       1       8.7      14.0
# 19  1756764000  2025-09-01 19:00    14.8    58.6       0       8.9      14.4
# 20  1756767600  2025-09-01 20:00    14.8    58.6       0       9.4      15.1
# 21  1756771200  2025-09-01 21:00    14.5    58.0       0       8.7      14.0
# 22  1756774800  2025-09-01 22:00    14.3    57.8       0       8.3      13.3
# 23  1756778400  2025-09-01 23:00    14.2    57.6       0       8.3      13.3
#
#     wind_degree wind_dir  pressure_mb  pressure_in  precip_mm  precip_in  \
# 0            85        E       1025.0        30.26       0.00        0.0
# 1            83        E       1024.0        30.25       0.00        0.0
# 2            85        E       1024.0        30.24       0.00        0.0
# 3            86        E       1024.0        30.24       0.01        0.0
# 4            86        E       1024.0        30.24       0.01        0.0
# 5            82        E       1024.0        30.25       0.00        0.0
# 19         56.9         14.8         58.6        13.0        55.5
# 20         56.8         14.8         58.6        12.9        55.2
# 21         56.3         14.5         58.0        12.3        54.2
# 22         56.2         14.4         57.8        12.2        54.0
# 23         56.0         14.2         57.6        11.9        53.5
#
#     will_it_rain  chance_of_rain  will_it_snow  chance_of_snow  vis_km  \
# 0              0               0             0               0    10.0
# 1              0               0             0               0    10.0
# 2              0               0             0               0    10.0
# 3              1              81             0               0    10.0
# 4              0              62             0               0    10.0
# 5              0               0             0               0    10.0
# 6              0               0             0               0    10.0
# 7              0               0             0               0    10.0
# 8              0              64             0               0    10.0
# 9              0              62             0               0    10.0
# 10             1              73             0               0    10.0
# 11             1              77             0               0    10.0
# 12             1              78             0               0    10.0
# 13             0              69             0               0    10.0
# 14             1             100             0               0    10.0
# 15             0              65             0               0    10.0
# 16             1              79             0               0    10.0
# 17             0               0             0               0    10.0
# 18             0               0             0               0    10.0
# 19             0               0             0               0    10.0
# 20             0               0             0               0    10.0
# 21             0               0             0               0    10.0
# 22             0               0             0               0    10.0
# 23             0               0             0               0    10.0
#
#     vis_miles  gust_mph  gust_kph   uv  short_rad  diff_rad       dni     gti  \
# 0         6.0      12.2      19.7  0.0       0.00      0.00      0.00    0.00
# 1         6.0      10.7      17.2  0.0       0.00      0.00      0.00    0.00
# 2         6.0      10.5      16.8  0.0       0.00      0.00      0.00    0.00
# 3         6.0       8.0      12.9  0.0       0.00      0.00      0.00    0.00
# 4         6.0       8.9      14.3  0.0       0.00      0.00      0.00    0.00
# 5         6.0      10.2      16.4  0.0       0.00      0.00      0.00    0.00
# 6         6.0       9.3      14.9  0.0       0.00      0.00      0.00    0.00
# 7         6.0       9.3      15.0  0.1       0.75      0.43      0.47    0.61
# 8         6.0       9.6      15.4  0.3       7.28      4.25      3.87    5.97
# 9         6.0       8.2      13.2  0.8      18.67     10.95      9.29   15.38
# 10        6.0       8.2      13.2  1.5     119.74     70.85     59.75   98.78
# 11        6.0       9.0      14.5  4.4     299.34    142.77    210.09  234.26
# 12        6.0       9.5      15.3  6.7     445.76    173.85    440.49  330.63
# 13        6.0       9.5      15.3  7.6     544.08    173.49    836.30  374.06
# 14        6.0       9.9      15.9  6.0     590.62    174.43   1773.57  345.39
# 15        6.0       9.8      15.7  3.4     591.25    174.78  68222.90    0.00
# 16        6.0      10.0      16.2  1.3     441.00    120.54      0.00  118.98
# 17        6.0      11.1      17.9  0.4     358.32     99.63      0.00   98.28
# 18        6.0      12.2      19.7  0.0     263.44     76.51      0.00   75.36
# 19        6.0      12.4      19.9  0.0       0.00      0.00      0.00    0.00
# 20        6.0      12.7      20.4  0.0       0.00      0.00      0.00    0.00
# 21        6.0      11.8      19.0  0.0       0.00      0.00      0.00    0.00
# 22        6.0      11.2      18.0  0.0       0.00      0.00      0.00    0.00
# 23        6.0      11.3      18.2  0.0       0.00      0.00      0.00    0.00
#
#                       condition.text  \
# 0               Parcialmente nublado
# 1               Parcialmente nublado
# 2                          Encoberto
# 3   Possibilidade de chuva irregular
# 4   Possibilidade de chuva irregular
# 5                            Nublado
# 6                          Encoberto
# 7                          Encoberto
# 8   Possibilidade de chuva irregular
# 9   Possibilidade de chuva irregular
# 10  Possibilidade de chuva irregular
# 11  Possibilidade de chuva irregular
# 12  Possibilidade de chuva irregular
# 13  Possibilidade de chuva irregular
# 14  Possibilidade de chuva irregular
# 15  Possibilidade de chuva irregular
# 16  Possibilidade de chuva irregular
# 17                           Nublado
# 18                           Nublado
# 19                           Nublado
# 20                           Nublado
# 21                           Nublado
# 22              Parcialmente nublado
# 23              Parcialmente nublado
#
#                                       condition.icon  condition.code
# 0   //cdn.weatherapi.com/weather/64x64/night/116.png            1003
# 1   //cdn.weatherapi.com/weather/64x64/night/116.png            1003
# 2   //cdn.weatherapi.com/weather/64x64/night/122.png            1009
# 3   //cdn.weatherapi.com/weather/64x64/night/176.png            1063
# 4   //cdn.weatherapi.com/weather/64x64/night/176.png            1063
# 5   //cdn.weatherapi.com/weather/64x64/night/119.png            1006
# 6   //cdn.weatherapi.com/weather/64x64/night/122.png            1009
# 7     //cdn.weatherapi.com/weather/64x64/day/122.png            1009
# 8     //cdn.weatherapi.com/weather/64x64/day/176.png            1063
# 9     //cdn.weatherapi.com/weather/64x64/day/176.png            1063
# 10    //cdn.weatherapi.com/weather/64x64/day/176.png            1063
# 11    //cdn.weatherapi.com/weather/64x64/day/176.png            1063
# 12    //cdn.weatherapi.com/weather/64x64/day/176.png            1063
# 13    //cdn.weatherapi.com/weather/64x64/day/176.png            1063
# 14    //cdn.weatherapi.com/weather/64x64/day/176.png            1063
# 15    //cdn.weatherapi.com/weather/64x64/day/176.png            1063
# 16    //cdn.weatherapi.com/weather/64x64/day/176.png            1063
# 17    //cdn.weatherapi.com/weather/64x64/day/119.png            1006
# 18    //cdn.weatherapi.com/weather/64x64/day/119.png            1006
# 19  //cdn.weatherapi.com/weather/64x64/night/119.png            1006
# 20  //cdn.weatherapi.com/weather/64x64/night/119.png            1006
# 21  //cdn.weatherapi.com/weather/64x64/night/119.png            1006
# 22  //cdn.weatherapi.com/weather/64x64/night/116.png            1003
# 23  //cdn.weatherapi.com/weather/64x64/night/116.png            1003

# %%
# Lista apenas com as colunas importantes
colunas_importantes = [
    "time",
    "feelslike_c",
    "humidity",
    "cloud",
    "uv",
    "wind_kph",
    "will_it_rain",
    "chance_of_rain",
    "will_it_snow",
    "chance_of_snow"
]

df_limpo = df_hour[colunas_importantes]
df_limpo.sample(5)
# Out:
#                 time  feelslike_c  humidity  cloud   uv  wind_kph  \
# 8   2025-09-01 08:00         15.4        82     91  0.3      12.2
# 5   2025-09-01 05:00         13.5        88     64  0.0      11.9
# 6   2025-09-01 06:00         13.7        89     91  0.0      10.8
# 10  2025-09-01 10:00         17.8        74     92  1.5      11.5
# 20  2025-09-01 20:00         13.8        88     69  0.0      15.1
#
#     will_it_rain  chance_of_rain  will_it_snow  chance_of_snow
# 8              0              64             0               0
# 5              0               0             0               0
# 6              0               0             0               0
# 10             1              73             0               0
# 20             0               0             0               0

# %%
df_hour.columns
# Out:
# Index(['time_epoch', 'time', 'temp_c', 'temp_f', 'is_day', 'wind_mph',
#        'wind_kph', 'wind_degree', 'wind_dir', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'snow_cm', 'humidity', 'cloud', 'feelslike_c',
#        'feelslike_f', 'windchill_c', 'windchill_f', 'heatindex_c',
#        'heatindex_f', 'dewpoint_c', 'dewpoint_f', 'will_it_rain',
#        'chance_of_rain', 'will_it_snow', 'chance_of_snow', 'vis_km',
#        'vis_miles', 'gust_mph', 'gust_kph', 'uv', 'short_rad', 'diff_rad',
#        'dni', 'gti', 'condition.text', 'condition.icon', 'condition.code'],
#       dtype='object')
